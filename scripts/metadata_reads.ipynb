# %%
import pandas as pd
import requests
# Out:
# Running cells with 'prefect' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -n prefect ipykernel --update-deps --force-reinstall'

# %%
account_id = "60a02238-cfc1-4e3d-9784-53f5ea65191b"
workspace_id= "20d43868-3e22-440c-9bb2-dc9e1b51126f"
id =  "13218581-1c21-4cf4-ac82-ae5cb9a490df"
params = { 
        "Flow.id" : "13218581-1c21-4cf4-ac82-ae5cb9a490df"
}

response = requests.get(f"https://api.prefect.cloud/api/accounts/{account_id}/workspaces/{workspace_id}/flow_runs/{id}")

# %%
import requests
import json

account_id = "60a02238-cfc1-4e3d-9784-53f5ea65191b"
workspace_id= "20d43868-3e22-440c-9bb2-dc9e1b51126f"

PREFECT_API_URL=f"https://api.prefect.cloud/api/accounts/{account_id}/workspaces/{workspace_id}"
PREFECT_API_KEY="pnu_PxirMNgAXP5xsEIXNqEziqQpJikcJ81CyfHe"
id = "e24a3c83-06c8-4984-bef8-cdecf795b9c7"
data = {
    "sort": "CREATED_DESC",
    "limit": 5,
    "offset": 0
}


headers = {"Authorization": f"Bearer {PREFECT_API_KEY}", 'Content-Type': 'application/json'}
endpoint = f"{PREFECT_API_URL}" + f"/deployments/{id}"

response = requests.request("GET",endpoint, headers=headers)
print(response.json())
# Out:
# {'id': 'e24a3c83-06c8-4984-bef8-cdecf795b9c7', 'created': '2023-08-18T17:07:19.875359+00:00', 'updated': '2023-08-18T17:07:19.871411+00:00', 'name': 'arthur', 'version': None, 'description': None, 'flow_id': '1e9f0211-f2c5-466e-8293-83ee62253ba4', 'schedule': None, 'is_schedule_active': True, 'infra_overrides': {'image': 'jllsbxprefect.azurecr.io/jllsbxprefect/prefectkube'}, 'parameters': {'name': 'Arthur'}, 'pull_steps': [{'prefect.projects.steps.set_working_directory': {'directory': '/opt/prefect/prefect_acr'}}], 'tags': ['remote', 'eks', '3f88a0c'], 'work_queue_name': 'default', 'parameter_openapi_schema': {'type': 'object', 'title': 'Parameters', 'properties': {'name': {'type': 'string', 'title': 'name', 'default': 'Marvin', 'position': 0}}}, 'path': None, 'entrypoint': 'flows/hello.py:hello', 'manifest_path': None, 'storage_document_id': None, 'infrastructure_document_id': None, 'created_by': {'id': '1a5adfde-5d44-44b9-b7ab-4a0ce2e5f77d', 'type': 'USER', 'display_value': 'nitinkeshavboutlookcom'}, 'updated_by': {'id': '1a5adfde-5d44-44b9-b7ab-4a0ce2e5f77d', 'type': 'USER', 'display_value': 'nitinkeshavboutlookcom'}, 'work_pool_name': 'kubernetes'}

# %%
import requests
import json

account_id = "60a02238-cfc1-4e3d-9784-53f5ea65191b"
workspace_id= "20d43868-3e22-440c-9bb2-dc9e1b51126f"

PREFECT_API_URL=f"https://api.prefect.cloud/api/accounts/{account_id}/workspaces/{workspace_id}"
PREFECT_API_KEY="pnu_PxirMNgAXP5xsEIXNqEziqQpJikcJ81CyfHe"
id = "e24a3c83-06c8-4984-bef8-cdecf795b9c7"
data = {
    "sort": "CREATED_DESC",
    "limit": 1,
    "offset": 0
}


headers = {"Authorization": f"Bearer {PREFECT_API_KEY}", 'Content-Type': 'application/json'}
endpoint = f"{PREFECT_API_URL}" + f"/deployments/count"

response = requests.request("POST",endpoint, headers=headers)
print(response.json())
# Out:
# 2

# %%
import requests
import json
import pandas  as pd
account_id = "60a02238-cfc1-4e3d-9784-53f5ea65191b"
workspace_id= "20d43868-3e22-440c-9bb2-dc9e1b51126f"

PREFECT_API_URL=f"https://api.prefect.cloud/api/accounts/{account_id}/workspaces/{workspace_id}"
PREFECT_API_KEY="pnu_PxirMNgAXP5xsEIXNqEziqQpJikcJ81CyfHe"
id = "e24a3c83-06c8-4984-bef8-cdecf795b9c7"
data = {
    "sort": "CREATED_DESC",
    "limit": 10,
    "offset": 0
}


headers = {"Authorization": f"Bearer {PREFECT_API_KEY}", 'Content-Type': 'application/json'}
endpoint = f"{PREFECT_API_URL}" + f"/deployments/filter"

response = requests.request("POST",endpoint, headers=headers)
pd.json_normalize(response.json())
# Out:
#                                      id                           created  \
# 0  e24a3c83-06c8-4984-bef8-cdecf795b9c7  2023-08-18T17:07:19.875359+00:00
# 1  d4803c72-91a7-444c-ac7a-bb4b464e91a2  2023-08-18T17:07:37.666222+00:00
#
#                             updated                name version description  \
# 0  2023-08-18T17:07:19.871411+00:00              arthur    None        None
# 1  2023-08-18T17:07:37.661847+00:00  databricks_execute    None        None
#
#                                 flow_id schedule  is_schedule_active  \
# 0  1e9f0211-f2c5-466e-8293-83ee62253ba4     None                True
# 1  13218581-1c21-4cf4-ac82-ae5cb9a490df     None                True
#
#                                           pull_steps  ... updated_by.type  \
# 0  [{'prefect.projects.steps.set_working_director...  ...            USER
# 1  [{'prefect.projects.steps.set_working_director...  ...            USER
#
#   updated_by.display_value parameters.job_id  \
# 0   nitinkeshavboutlookcom               NaN
# 1   nitinkeshavboutlookcom   157107892089699
#
#   parameters.databricks_credentials_block_name  \
# 0                                          NaN
# 1                           qa-databricks-repo
#
#              parameter_openapi_schema.required  \
# 0                                          NaN
# 1  [databricks_credentials_block_name, job_id]
#
#   parameter_openapi_schema.properties.job_id.title  \
# 0                                              NaN
# 1                                           job_id
#
#   parameter_openapi_schema.properties.job_id.position  \
# 0                                                NaN
# 1                                                1.0
#
#   parameter_openapi_schema.properties.databricks_credentials_block_name.type  \
# 0                                                NaN
# 1                                             string
#
#   parameter_openapi_schema.properties.databricks_credentials_block_name.title  \
# 0                                                NaN
# 1                  databricks_credentials_block_name
#
#   parameter_openapi_schema.properties.databricks_credentials_block_name.position
# 0                                                NaN
# 1                                                0.0
#
# [2 rows x 40 columns]

# %%
import requests
import json
import pandas  as pd
account_id = "60a02238-cfc1-4e3d-9784-53f5ea65191b"
workspace_id= "20d43868-3e22-440c-9bb2-dc9e1b51126f"

PREFECT_API_URL=f"https://api.prefect.cloud/api/accounts/{account_id}/workspaces/{workspace_id}"
PREFECT_API_KEY="pnu_PxirMNgAXP5xsEIXNqEziqQpJikcJ81CyfHe"
id = "e24a3c83-06c8-4984-bef8-cdecf795b9c7"
payload = json.dumps({
    "deployments": {
        "operator": "and_",
        "id": {
        "any_": ["e24a3c83-06c8-4984-bef8-cdecf795b9c7"]
        }
    },
    "limit": 2,
    "sort": "NAME_DESC",
    "offset": 0,
    "flows": {
        "operator": "and_",
        "id": {
        "any_": ["1e9f0211-f2c5-466e-8293-83ee62253ba4"]
        }    }

    

    })

headers = {"Authorization": f"Bearer {PREFECT_API_KEY}", 'Content-Type': 'application/json'}
endpoint = f"{PREFECT_API_URL}" + "/flow_runs/filter"

response = requests.request("POST", endpoint, headers=headers, data = payload)
print(response.json())
# Out:
# [{'id': '1ae67833-82bf-4a1f-b0d0-27d8e5f23fca', 'created': '2023-08-18T17:08:13.185145+00:00', 'updated': '2023-08-18T17:09:21.152909+00:00', 'name': 'golden-junglefowl', 'flow_id': '1e9f0211-f2c5-466e-8293-83ee62253ba4', 'state_id': '4a865b91-28f3-49df-a805-db5f16ad6c08', 'deployment_id': 'e24a3c83-06c8-4984-bef8-cdecf795b9c7', 'work_queue_id': '22f11604-3a94-4bd5-8d4c-3ec4e0cf2e32', 'work_queue_name': 'default', 'flow_version': '593dc587a88c131f40b6c8a78377555d', 'parameters': {'name': 'Arthur'}, 'idempotency_key': None, 'context': {}, 'empirical_policy': {'max_retries': 0, 'retry_delay_seconds': 0.0, 'retries': 0, 'retry_delay': 0, 'pause_keys': [], 'resuming': False}, 'tags': ['3f88a0c', 'remote', 'eks'], 'parent_task_run_id': None, 'state_type': 'COMPLETED', 'state_name': 'Completed', 'run_count': 1, 'expected_start_time': '2023-08-18T17:08:13.185047+00:00', 'next_scheduled_start_time': None, 'start_time': '2023-08-18T17:08:36.318931+00:00', 'end_time': '2023-08-18T17:08:37.067523+00:00', 'total_run_time': 0.748592, 'estimated_run_time': 0.748592, 'estimated_start_time_delta': 23.133884, 'auto_scheduled': False, 'infrastructure_document_id': None, 'infrastructure_pid': 'ba5ec623-308f-458c-b219-24077f753240:prefect:golden-junglefowl-9k67k', 'created_by': {'id': '1a5adfde-5d44-44b9-b7ab-4a0ce2e5f77d', 'type': 'USER', 'display_value': 'nitinkeshavboutlookcom'}, 'work_pool_id': 'd26c7f44-a66f-45af-b763-379f235cbba0', 'work_pool_name': 'kubernetes', 'state': {'id': '4a865b91-28f3-49df-a805-db5f16ad6c08', 'type': 'COMPLETED', 'name': 'Completed', 'timestamp': '2023-08-18T17:08:37.067523+00:00', 'message': None, 'data': {'type': 'unpersisted'}, 'state_details': {'flow_run_id': '1ae67833-82bf-4a1f-b0d0-27d8e5f23fca', 'task_run_id': None, 'child_flow_run_id': None, 'scheduled_time': None, 'cache_key': None, 'cache_expiration': None, 'untrackable_result': False, 'pause_timeout': None, 'pause_reschedule': False, 'pause_key': None, 'refresh_cache': None}}}]
