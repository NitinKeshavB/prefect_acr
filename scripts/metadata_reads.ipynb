# %%
import pandas as pd
import requests

# %%
account_id = "60a02238-cfc1-4e3d-9784-53f5ea65191b"
workspace_id= "20d43868-3e22-440c-9bb2-dc9e1b51126f"
id =  "13218581-1c21-4cf4-ac82-ae5cb9a490df"
params = { 
        "Flow.id" : "13218581-1c21-4cf4-ac82-ae5cb9a490df"
}

response = requests.get(f"https://api.prefect.cloud/api/accounts/{account_id}/workspaces/{workspace_id}/flow_runs/{id}")

# %%
import requests
import json

account_id = "60a02238-cfc1-4e3d-9784-53f5ea65191b"
workspace_id= "20d43868-3e22-440c-9bb2-dc9e1b51126f"

PREFECT_API_URL=f"https://api.prefect.cloud/api/accounts/{account_id}/workspaces/{workspace_id}"
PREFECT_API_KEY="pnu_PxirMNgAXP5xsEIXNqEziqQpJikcJ81CyfHe"
id = "08431b26-b8b3-4ec9-a396-54aedc5d0740"
data = {
    "sort": "CREATED_DESC",
    "limit": 5,
    "offset": 0
}


headers = {"Authorization": f"Bearer {PREFECT_API_KEY}", 'Content-Type': 'application/json'}
endpoint = f"{PREFECT_API_URL}" + f"/deployments/{id}"

response = requests.request("GET",endpoint, headers=headers)
print(response.json())
# Out:
# {'id': '08431b26-b8b3-4ec9-a396-54aedc5d0740', 'created': '2023-08-26T00:25:14.952278+00:00', 'updated': '2023-08-26T02:52:48.189770+00:00', 'name': 'gpa_landing_capf', 'version': None, 'description': None, 'flow_id': '7157ca8c-731d-4a15-a28f-b8b650f99a5c', 'schedule': None, 'is_schedule_active': True, 'infra_overrides': {'image': 'jllsbxprefect.azurecr.io/jllsbxprefect/prefectkube'}, 'parameters': {'job_id': '157107892089699', 'databricks_credentials_block_name': 'qa-databricks-repo'}, 'pull_steps': [{'prefect.projects.steps.set_working_directory': {'directory': '/opt/prefect/prefect_acr'}}], 'tags': ['group:gpa'], 'work_queue_name': 'default', 'parameter_openapi_schema': {'type': 'object', 'title': 'Parameters', 'required': ['databricks_credentials_block_name', 'job_id'], 'properties': {'job_id': {'title': 'job_id', 'position': 1}, 'databricks_credentials_block_name': {'type': 'string', 'title': 'databricks_credentials_block_name', 'position': 0}}}, 'path': None, 'entrypoint': 'flows/async_databricks_api_exec.py:databricks_job_submit', 'manifest_path': None, 'storage_document_id': None, 'infrastructure_document_id': None, 'created_by': {'id': '1a5adfde-5d44-44b9-b7ab-4a0ce2e5f77d', 'type': 'USER', 'display_value': 'nitinkeshavboutlookcom'}, 'updated_by': {'id': '1a5adfde-5d44-44b9-b7ab-4a0ce2e5f77d', 'type': 'USER', 'display_value': 'nitinkeshavboutlookcom'}, 'work_pool_name': 'kubernetes'}

# %%
import requests
import json

account_id = "60a02238-cfc1-4e3d-9784-53f5ea65191b"
workspace_id= "20d43868-3e22-440c-9bb2-dc9e1b51126f"

PREFECT_API_URL=f"https://api.prefect.cloud/api/accounts/{account_id}/workspaces/{workspace_id}"
PREFECT_API_KEY="pnu_PxirMNgAXP5xsEIXNqEziqQpJikcJ81CyfHe"
id = "e24a3c83-06c8-4984-bef8-cdecf795b9c7"
data = {
    "sort": "CREATED_DESC",
    "limit": 1,
    "offset": 0
}


headers = {"Authorization": f"Bearer {PREFECT_API_KEY}", 'Content-Type': 'application/json'}
endpoint = f"{PREFECT_API_URL}" + f"/deployments/count"

response = requests.request("POST",endpoint, headers=headers)
print(response.json())
# Out:
# 5

# %%
import requests
import json
import pandas  as pd
account_id = "60a02238-cfc1-4e3d-9784-53f5ea65191b"
workspace_id= "20d43868-3e22-440c-9bb2-dc9e1b51126f"

PREFECT_API_URL=f"https://api.prefect.cloud/api/accounts/{account_id}/workspaces/{workspace_id}"
PREFECT_API_KEY="pnu_PxirMNgAXP5xsEIXNqEziqQpJikcJ81CyfHe"
id = "e24a3c83-06c8-4984-bef8-cdecf795b9c7"
data = {
    "sort": "CREATED_DESC",
    "limit": 10,
    "offset": 0
}


headers = {"Authorization": f"Bearer {PREFECT_API_KEY}", 'Content-Type': 'application/json'}
endpoint = f"{PREFECT_API_URL}" + f"/deployments/filter"

response = requests.request("POST",endpoint, headers=headers)
pd.json_normalize(response.json())
# Out:
#                                      id                           created  \
# 0  08431b26-b8b3-4ec9-a396-54aedc5d0740  2023-08-26T00:25:14.952278+00:00
# 1  272a9ef9-1e04-4af3-baac-953e96535d63  2023-08-26T00:25:48.361731+00:00
# 2  c4685f54-7f8f-4a2a-9eb6-a939cbcea103  2023-08-26T00:24:59.144127+00:00
# 3  7890df47-d9fa-4fd9-8b57-33701be29663  2023-08-26T00:25:32.770984+00:00
# 4  f44a22d3-9b83-4d52-94b6-62496492ded5  2023-08-26T00:26:04.880097+00:00
#
#                             updated                name version description  \
# 0  2023-08-26T02:52:48.189770+00:00    gpa_landing_capf    None        None
# 1  2023-08-26T02:53:19.547355+00:00  gpa_landing_datman    None        None
# 2  2023-08-26T02:52:32.810863+00:00     gpa_landing_gll    None        None
# 3  2023-08-26T02:53:03.895422+00:00     gpa_landing_hff    None        None
# 4  2023-08-26T02:53:33.977868+00:00     gpa_landing_pix    None        None
#
#                                 flow_id schedule  is_schedule_active  \
# 0  7157ca8c-731d-4a15-a28f-b8b650f99a5c     None                True
# 1  7157ca8c-731d-4a15-a28f-b8b650f99a5c     None                True
# 2  eda3c5fd-5cb9-4032-b723-c74f412aa4ee     None                True
# 3  7157ca8c-731d-4a15-a28f-b8b650f99a5c     None                True
# 4  7157ca8c-731d-4a15-a28f-b8b650f99a5c     None                True
#
#                                           pull_steps  ...  \
# 0  [{'prefect.projects.steps.set_working_director...  ...
# 1  [{'prefect.projects.steps.set_working_director...  ...
# 2  [{'prefect.projects.steps.set_working_director...  ...
# 3  [{'prefect.projects.steps.set_working_director...  ...
# 4  [{'prefect.projects.steps.set_working_director...  ...
#
#                           updated_by.id updated_by.type  \
# 0  1a5adfde-5d44-44b9-b7ab-4a0ce2e5f77d            USER
# 1  1a5adfde-5d44-44b9-b7ab-4a0ce2e5f77d            USER
# 2  1a5adfde-5d44-44b9-b7ab-4a0ce2e5f77d            USER
# 3  1a5adfde-5d44-44b9-b7ab-4a0ce2e5f77d            USER
# 4  1a5adfde-5d44-44b9-b7ab-4a0ce2e5f77d            USER
#
#   updated_by.display_value                   parameters.sql_query  \
# 0   nitinkeshavboutlookcom                                    NaN
# 1   nitinkeshavboutlookcom                                    NaN
# 2   nitinkeshavboutlookcom  select public.get_common_actor_name()
# 3   nitinkeshavboutlookcom                                    NaN
# 4   nitinkeshavboutlookcom                                    NaN
#
#   parameters.db_credentials_block_name  \
# 0                                  NaN
# 1                                  NaN
# 2              async-metadata-db-pgsql
# 3                                  NaN
# 4                                  NaN
#
#   parameter_openapi_schema.properties.sql_query.title  \
# 0                                                NaN
# 1                                                NaN
# 2                                          sql_query
# 3                                                NaN
# 4                                                NaN
#
#   parameter_openapi_schema.properties.sql_query.position  \
# 0                                                NaN
# 1                                                NaN
# 2                                                1.0
# 3                                                NaN
# 4                                                NaN
#
#   parameter_openapi_schema.properties.db_credentials_block_name.type  \
# 0                                                NaN
# 1                                                NaN
# 2                                             string
# 3                                                NaN
# 4                                                NaN
#
#   parameter_openapi_schema.properties.db_credentials_block_name.title  \
# 0                                                NaN
# 1                                                NaN
# 2                          db_credentials_block_name
# 3                                                NaN
# 4                                                NaN
#
#   parameter_openapi_schema.properties.db_credentials_block_name.position
# 0                                                NaN
# 1                                                NaN
# 2                                                0.0
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 42 columns]

# %%
import requests
import json
import pandas  as pd
account_id = "60a02238-cfc1-4e3d-9784-53f5ea65191b"
workspace_id= "20d43868-3e22-440c-9bb2-dc9e1b51126f"

PREFECT_API_URL=f"https://api.prefect.cloud/api/accounts/{account_id}/workspaces/{workspace_id}"
PREFECT_API_KEY="pnu_PxirMNgAXP5xsEIXNqEziqQpJikcJ81CyfHe"
id = "e24a3c83-06c8-4984-bef8-cdecf795b9c7"
payload = json.dumps({
    "deployments": {
        "operator": "and_",
        "id": {
        "any_": ["e24a3c83-06c8-4984-bef8-cdecf795b9c7"]
        }
    },
    "limit": 2,
    "sort": "NAME_DESC",
    "offset": 0,
    "flows": {
        "operator": "and_",
        "id": {
        "any_": ["1e9f0211-f2c5-466e-8293-83ee62253ba4"]
        }    }

    

    })

headers = {"Authorization": f"Bearer {PREFECT_API_KEY}", 'Content-Type': 'application/json'}
endpoint = f"{PREFECT_API_URL}" + "/flow_runs/filter"

response = requests.request("POST", endpoint, headers=headers, data = payload)
print(response.json())
# Out:
# []

# %%
import requests
import json
import pandas  as pd
account_id = "60a02238-cfc1-4e3d-9784-53f5ea65191b"
workspace_id= "20d43868-3e22-440c-9bb2-dc9e1b51126f"

PREFECT_API_URL=f"https://api.prefect.cloud/api/accounts/{account_id}/workspaces/{workspace_id}"
PREFECT_API_KEY="pnu_PxirMNgAXP5xsEIXNqEziqQpJikcJ81CyfHe"
id = "e24a3c83-06c8-4984-bef8-cdecf795b9c7"
l="'abc','cde'"
payload = json.dumps({
    "tags":   [  "abc1" ,
                "cde1"
             ]
        

    })

headers = {"Authorization": f"Bearer {PREFECT_API_KEY}", 'Content-Type': 'application/json'}
endpoint = f"https://api.prefect.cloud/api/accounts/{account_id}/workspaces/{workspace_id}/flow_runs/2170a54f-a236-4382-91f8-96cd45ffa4b6"

response = requests.request("PATCH", endpoint, headers=headers, data = payload)
print(response.json())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 12
#       9 id = "e24a3c83-06c8-4984-bef8-cdecf795b9c7"
#      10 l="'abc','cde'"
#      11 payload = json.dumps({
# ---> 12     "tags": {
#      13
#      14             ["abc1","cde1"]
#      15         }
#      16
#      17     })
#      19 headers = {"Authorization": f"Bearer {PREFECT_API_KEY}", 'Content-Type': 'application/json'}
#      20 endpoint = f"https://api.prefect.cloud/api/accounts/{account_id}/workspaces/{workspace_id}/flow_runs/2170a54f-a236-4382-91f8-96cd45ffa4b6"
#
# TypeError: unhashable type: 'list'
